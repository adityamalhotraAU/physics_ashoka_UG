# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $\text{Bode Plot for high-pass filter}$

# %%
log_freq, gain = np.loadtxt("./high_pass_bode.txt", unpack = True)

# %%
#Error for high pass
vin1, vout1 = np.loadtxt("./vin_vout_high_pass.txt", unpack = True)
err_highpass = np.sqrt((0.16/vin1**2)+(16/vout1**2))/(np.log(10))
plt.scatter(log_freq, err_highpass)
plt.xlabel(r"Frequency in log scale")
plt.ylabel(r"Relative error in measuring gain")
gain_err1 = np.abs(gain*err_highpass)
for i in range(0,len(err_highpass)):
    print(np.round(gain[i],2), "&", np.round(err_highpass[i]*100, 2), "\\\\", "\hline")
# Out:
# -4.82 & 70.16 \\ \hline
# 0.95 & 37.67 \\ \hline
# 5.67 & 22.56 \\ \hline
# 4.27 & 25.89 \\ \hline
# 7.62 & 17.87 \\ \hline
# 8.63 & 16.66 \\ \hline
# 9.93 & 14.22 \\ \hline
# 11.65 & 11.92 \\ \hline
# 13.63 & 9.83 \\ \hline
# 14.81 & 9.01 \\ \hline
# 15.71 & 8.34 \\ \hline
# 16.26 & 7.97 \\ \hline
# 17.38 & 7.3 \\ \hline
# 18.06 & 6.95 \\ \hline
# 18.49 & 6.75 \\ \hline
# 18.99 & 6.53 \\ \hline
# 19.18 & 6.45 \\ \hline
# 19.37 & 6.38 \\ \hline
# 19.55 & 6.31 \\ \hline
# 19.55 & 6.31 \\ \hline
# 19.55 & 6.31 \\ \hline
# 19.55 & 6.31 \\ \hline
# 19.91 & 6.43 \\ \hline
# 19.82 & 6.47 \\ \hline
# 19.71 & 6.94 \\ \hline
# 19.71 & 6.79 \\ \hline
# 19.83 & 5.96 \\ \hline
# 19.83 & 5.96 \\ \hline

# %%
plt.scatter(log_freq, gain, color = 'firebrick')
plt.plot(log_freq, gain, '--', color = 'blue')
plt.axvline(3.08,color = 'tomato', label = r"$\omega = \omega_c$")
plt.xlabel(r"Frequency (log scale)")
plt.ylabel(r"Gain (dB)")
plt.errorbar(log_freq, gain, yerr = gain_err1, ecolor= 'black', capsize = 3, ls = "none")
plt.legend()
plt.show()

# %% [markdown]
# $\text{Bode plot for low-pass filter}$

# %%
log_freq2, gain2 = np.loadtxt("./low_pass_bode.txt", unpack = True)

# %%
#error in low-pass
vin2, vout2 = np.loadtxt("./vin_vout_low_pass.txt", unpack = True)
err_lowpass = np.sqrt((0.16/vin2**2)+(16/vout2**2))/(np.log(10))
plt.scatter(log_freq2, err_lowpass)
plt.xlabel(r"Frequency in log scale")
plt.ylabel(r"Relative error in measuring gain")
gain_err2 = np.abs(gain2*err_lowpass)
for i in range(0,len(err_lowpass)):
    print(np.round(gain2[i],2), "&", np.round(err_lowpass[i]*100, 2), "\\\\", "\hline")
# Out:
# 19.82 & 6.2 \\ \hline
# 19.66 & 6.02 \\ \hline
# 19.82 & 6.2 \\ \hline
# 19.65 & 6.27 \\ \hline
# 19.28 & 6.41 \\ \hline
# 18.89 & 6.57 \\ \hline
# 18.49 & 6.75 \\ \hline
# 17.15 & 7.43 \\ \hline
# 16.9 & 7.57 \\ \hline
# 16.39 & 7.88 \\ \hline
# 15.56 & 8.44 \\ \hline
# 13.98 & 9.71 \\ \hline
# 12.04 & 11.69 \\ \hline
# 10.1 & 14.25 \\ \hline
# 8.94 & 16.11 \\ \hline
# 7.6 & 18.61 \\ \hline
# 6.02 & 22.14 \\ \hline
# 4.08 & 27.49 \\ \hline
# 1.58 & 36.45 \\ \hline

# %%
plt.scatter(log_freq2, gain2, color = 'firebrick')
plt.plot(log_freq2, gain2, '--', color = 'blue')
plt.axvline(3.25, color = 'tomato', label = r"$\omega = \omega_c$")
plt.xlabel(r"Frequency (log scale)")
plt.ylabel(r"Gain (dB)")
plt.errorbar(log_freq2, gain2, yerr = gain_err2, ecolor = 'black', capsize = 3, ls = 'none')
plt.legend()
plt.show()

# %% [markdown]
# $\text{Bode plot for LCR series configuration}$

# %%
lcr_freq_series, gain_series = np.loadtxt("./LCR_Series.txt", unpack = True)

# %%
#error in lcr series
vin3, vout3 = np.loadtxt("./vin_vout_lcr_series.txt", unpack = True)
err_lcr_series = np.sqrt((0.16/vin3**2)+(16/vout3**2))/(np.log(10))
plt.scatter(lcr_freq_series, err_lcr_series)
plt.xlabel(r"Frequency in log scale")
plt.ylabel(r"Relative error in measuring gain")
gain_err3 = np.abs(err_lcr_series * gain_series)
for i in range(0,len(err_lcr_series)):
    print(np.round(gain_series[i],2), "&", np.round(err_lcr_series[i]*100, 2), "\\\\", "\hline")
# Out:
# 0.6 & 48.53 \\ \hline
# 4.25 & 29.34 \\ \hline
# 7.04 & 19.78 \\ \hline
# 8.98 & 20.05 \\ \hline
# 11.35 & 13.62 \\ \hline
# 14.88 & 9.74 \\ \hline
# 16.32 & 9.44 \\ \hline
# 17.57 & 8.0 \\ \hline
# 18.26 & 7.79 \\ \hline
# 18.26 & 7.79 \\ \hline
# 17.76 & 8.07 \\ \hline
# 17.08 & 8.9 \\ \hline
# 15.84 & 8.96 \\ \hline
# 14.51 & 9.64 \\ \hline
# 13.42 & 10.66 \\ \hline
# 11.24 & 13.21 \\ \hline
# 8.31 & 17.95 \\ \hline
# 6.44 & 21.13 \\ \hline
# 4.61 & 25.91 \\ \hline
# 2.92 & 31.32 \\ \hline
# 0.83 & 39.72 \\ \hline
# 0.0 & 43.65 \\ \hline

# %%
plt.scatter(lcr_freq_series, gain_series, color = 'firebrick')
plt.plot(lcr_freq_series, gain_series, '--', color = 'blue')
plt.axvline(3.45, color = 'tomato', label = r"$\omega = \omega_0$")
plt.xlabel(r"Frequency (log scale)")
plt.ylabel(r"Gain (dB)")
plt.errorbar(lcr_freq_series, gain_series, yerr = gain_err3, ecolor = 'black', capsize = 3, ls = 'none')
plt.legend()
plt.show()

# %% [markdown]
# $\text{Bode plot for LCR ``tank" configuration}$

# %%
lcr_freq_tank, gain_tank = np.loadtxt("./lcr_tank.txt", unpack = True)

# %%
#error in lcr tank
vin4, vout4 = np.loadtxt("./vin_vout_lcr_tank.txt", unpack = True)
err_lcr_tank = np.sqrt((0.16/vin4**2)+(16/vout4**2))/(np.log(10))
plt.scatter(lcr_freq_tank, err_lcr_tank)
plt.xlabel(r"Frequency in log scale")
plt.ylabel(r"Relative error in measuring gain")
gain_err4 = np.abs(err_lcr_tank*gain_tank)
for i in range(0,len(err_lcr_tank)):
    print(np.round(gain_tank[i],2), "&", np.round(err_lcr_tank[i]*100, 2), "\\\\", "\hline")
# Out:
# 18.37 & 9.72 \\ \hline
# 18.3 & 7.6 \\ \hline
# 17.82 & 7.86 \\ \hline
# 16.98 & 8.18 \\ \hline
# 16.33 & 8.8 \\ \hline
# 15.19 & 9.28 \\ \hline
# 13.6 & 10.7 \\ \hline
# 11.9 & 12.61 \\ \hline
# 9.12 & 16.13 \\ \hline
# 5.28 & 24.53 \\ \hline
# 1.18 & 39.74 \\ \hline
# -1.94 & 54.46 \\ \hline
# 2.28 & 33.69 \\ \hline
# 6.62 & 21.15 \\ \hline
# 10.0 & 14.69 \\ \hline
# 13.04 & 10.82 \\ \hline
# 14.67 & 9.5 \\ \hline
# 15.95 & 8.69 \\ \hline
# 16.39 & 8.39 \\ \hline
# 16.93 & 8.04 \\ \hline
# 17.5 & 7.87 \\ \hline
# 17.75 & 7.73 \\ \hline
# 18.42 & 7.54 \\ \hline
# 18.53 & 7.48 \\ \hline
# 18.98 & 7.26 \\ \hline
# 19.39 & 7.24 \\ \hline
# 19.39 & 7.24 \\ \hline
# 19.6 & 7.15 \\ \hline
# 19.7 & 7.1 \\ \hline
# 19.9 & 7.36 \\ \hline

# %%
plt.scatter(lcr_freq_tank, gain_tank, color = 'firebrick')
plt.plot(lcr_freq_tank, gain_tank, '--' ,color = 'blue')
plt.axvline(3.48, color = 'tomato', label = r"$\omega = \omega_0$")
plt.xlabel(r"Frequency (log scale)")
plt.ylabel(r"Gain (dB)")
plt.errorbar(lcr_freq_tank, gain_tank, yerr = gain_err4, ecolor = 'black', capsize = 3, ls = 'none')
plt.legend()
plt.show()

# %%
10**3.08* 2 * np.pi
# Out:
# 7554.050230932703

# %%
1.59 * 1000 * 2 * np.pi
# Out:
# 9990.264638415541

# %%
np.round((18.97-9.9)/9.9 * 100,2)
# Out:
# 91.62

# %%
(17.71-18.28)/18.28*100
# Out:
# -3.118161925601752
